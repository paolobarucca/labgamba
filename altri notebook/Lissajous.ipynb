# %%
# %pylab inline

Ax=1.
Ay=2.

fasex=0.4
fasey=1.

omegax=1.
omegay=sqrt(2)

maxt=20.
npunti=400
t=linspace(0,maxt,npunti)

x=Ax*cos(omegax*t+fasex)
y=Ay*cos(omegay*t+fasey)

plot(x,y)
# Out:
# Populating the interactive namespace from numpy and matplotlib
